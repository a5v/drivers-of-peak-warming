# %%
from peak_warming_calculator import *
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
sns.set_style("whitegrid")
plt.rc('font', family='serif')

# %%
from SALib.sample import saltelli
from SALib.analyze import sobol
import numpy as np
from numpy import genfromtxt
import matplotlib.cm as cm

# %%
import time

# %%
# from varying_g_peak_warming_calculator import *

# %% [markdown]
# ## Not Sampling s

# %%
consumption_growth_array = np.linspace(0.01, 0.03, 5)

# %%
consumption_growth_array
# Out:
# array([0.01 , 0.015, 0.02 , 0.025, 0.03 ])

# %%
# Define the model inputs
problem_2 = {
'num_vars': 2,
'names': ['P_50/P_100', 'P_100'],
'bounds': [[0.5, 0.8],
[100, 500]]
}
# Generate samples
param_values_2 = saltelli.sample(problem_2, 8)

# %%
param_values_2
# Out:
# array([[  0.528125, 287.5     ],
#        [  0.640625, 287.5     ],
#        [  0.528125, 362.5     ],
#        [  0.528125, 362.5     ],
#        [  0.640625, 287.5     ],
#        [  0.640625, 362.5     ],
#        [  0.678125, 487.5     ],
#        [  0.790625, 487.5     ],
#        [  0.678125, 162.5     ],
#        [  0.678125, 162.5     ],
#        [  0.790625, 487.5     ],
#        [  0.790625, 162.5     ],
#        [  0.753125, 187.5     ],
#        [  0.565625, 187.5     ],
#        [  0.753125, 462.5     ],
#        [  0.753125, 462.5     ],
#        [  0.565625, 187.5     ],
#        [  0.565625, 462.5     ],
#        [  0.603125, 387.5     ],
#        [  0.715625, 387.5     ],
#        [  0.603125, 262.5     ],
#        [  0.603125, 262.5     ],
#        [  0.715625, 387.5     ],
#        [  0.715625, 262.5     ],
#        [  0.640625, 137.5     ],
#        [  0.753125, 137.5     ],
#        [  0.640625, 212.5     ],
#        [  0.640625, 212.5     ],
#        [  0.753125, 137.5     ],
#        [  0.753125, 212.5     ],
#        [  0.790625, 337.5     ],
#        [  0.603125, 337.5     ],
#        [  0.790625, 412.5     ],
#        [  0.790625, 412.5     ],
#        [  0.603125, 337.5     ],
#        [  0.603125, 412.5     ],
#        [  0.715625, 237.5     ],
#        [  0.678125, 237.5     ],
#        [  0.715625, 112.5     ],
#        [  0.715625, 112.5     ],
#        [  0.678125, 237.5     ],
#        [  0.678125, 112.5     ],
#        [  0.565625, 437.5     ],
#        [  0.528125, 437.5     ],
#        [  0.565625, 312.5     ],
#        [  0.565625, 312.5     ],
#        [  0.528125, 437.5     ],
#        [  0.528125, 312.5     ]])

# %%
P_100_list = []

for i in range(len(param_values_2)):
    P_100_list.append(param_values_2[i][1])

# %%
def vary_consumption_growth2(consumption_growth):
    Y = np.zeros([param_values_2.shape[0]])
    SCC_forecasted_0 = np.zeros([param_values_2.shape[0]])
    T_year_list = np.zeros([param_values_2.shape[0]])

#     consumption_growth = 0.020
    consumption_discount = consumption_growth + 0.015

    for i in range(len(param_values_2)):
        if i%8 == 0:
            print(i)
            t = time.localtime()
            current_time = time.strftime("%H:%M:%S", t)
            print(current_time)
        
        P_50 = param_values_2[i][0]*param_values_2[i][1]
        P_100 = param_values_2[i][1]
        r = consumption_discount
        s = r * np.log(5)/np.log((P_100)/(P_50))
#         constraint = param_values_2[i][1]
#         s = r * np.log(constraint)/np.log((P_100 - P0)/(P_50 - P0))
#         s = r * np.log(constraint)/np.log((P_100)/(P_50))
        Y[i], SCC_forecasted, forecasted_abatement, forecasted_emissions, T_complete = peak_warming_calculator(P_50=P_50, P_100=P_100, consumption_growth=consumption_growth, consumption_discount=consumption_discount, return_all_output=True, s=s, r=r)
        SCC_forecasted_0[i] = SCC_forecasted[0]
        start_year = 1750
        peak_T = Y[i]
        T_year_list[i] = next(x[0] for x in enumerate(T_complete) if x[1] == peak_T) + start_year
        if Y[i] < 1.4:
            print(param_values_2[i][0])
            print(param_values_2[i][1])
            print(consumption_discount)
    return Y, SCC_forecasted_0, T_year_list

# %%
Y_array = []
SCC_0_array = []
T_year_array = []

for i in range(len(consumption_growth_array)):  # len(consumption_growth_array)
    Y, SCC_0, T_year = vary_consumption_growth2(consumption_growth_array[i])
    Y_array.append(Y)
    SCC_0_array.append(SCC_0)
    T_year_array.append(T_year)
# Out:
# 0
# 10:20:46
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# 8
# 10:21:53
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# 16
# 10:22:53
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# 24
# 10:23:58
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# 32
# 10:24:57
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# 40
# 10:25:57
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# 0
# 10:27:05
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# 8
# 10:27:43
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# 16
# 10:28:17
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# 24
# 10:28:54
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# 32
# 10:29:24
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# 40
# 10:30:00
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# 0
# 10:30:36
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# 8
# 10:30:57
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# 16
# 10:31:24
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# 24
# 10:31:51
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# 32
# 10:32:15
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# 40
# 10:32:39
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# 0
# 10:33:04
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# 8
# 10:33:32
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# 16
# 10:33:56
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# 24
# 10:34:15
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# 32
# 10:34:35
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# 40
# 10:34:54
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# 0
# 10:35:14
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# 8
# 10:35:32
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# 16
# 10:35:48
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# 24
# 10:36:06
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# 32
# 10:36:23
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# 40
# 10:36:39
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/peak_warming_calculator.py:252: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))

# %%
# colour_scheme = ["orange","blue","yellow","green","purple","red"]

# %%
fig = plt.figure()

## plot output

for i in range(len(Y_array)):
    plt.scatter(P_100_list, Y_array[i], label=np.round(consumption_growth_array[i]*100, 3), color=cm.plasma(i/len(Y_array)))

# plt.legend()
plt.rc('font', family='serif')

## plot curves from Myles' paper

# W0 = 75*10**12  
W0 = 80*10**12  
D0 = 0.00267
T_TCRE = 0.00054  # degrees Celsius per GtCO2
# note: this corresponds to 0.002 degrees Celsius per GtC
r_minus_g = 0.015  # 1.5%
ks = 0.12  # per year

G = W0*D0*T_TCRE*(1/(r_minus_g)-1/(ks+r_minus_g))

gamma = 2
# E_0 = 39  # 2014 level of emissions
# percentage_of_emissions = 0.75  # set here the percentage of emisison
# E_bar = percentage_of_emissions*E_0
E_bar = 0.75*40.040508
# T_0 = 0.9  # 1.0136929156818866  # degrees Celsius
# T_0 = 1.0136929156818866
T_0 = 1.2

T_m = np.arange(T_0, 5,0.1)
g_bar = np.arange(0.01, 0.04, 0.005)

for i in range(len(g_bar)):
    A_B = gamma*G*(T_m**(gamma-1))*np.exp((g_bar[i]/E_bar) * (T_m-T_0)/T_TCRE)
#     print(gamma, G, T_m)
#     print(np.exp((g_bar[i]/E_bar) * (T_m-T_0)/T_TCRE))
#     plt.plot(A_B*10**(-9), T_m, color="k")  # convert cost into trillions of dollars # , label=g_bar[i]
    plt.plot(A_B*10**(-9), T_m, color=cm.plasma(i/len(g_bar)))

plt.legend(title="g (% yr$^{-1}$)")
# plt.xlim(0, 530)
plt.xlim(0, 500)
plt.ylim(1.2, 5.2)
plt.xlabel("Carbon Price at 100% Abatement ($)")
plt.ylabel("Peak Warming (K)")

# plt.text(500, 2.3, '3.5', size="small")
# plt.text(500, 2.67, '3.0', size="small")
# plt.text(500, 2.92, '2.5', size="small")
# plt.text(500, 3.25, '2.0', size="small")
# plt.text(500, 3.75, '1.5', size="small")
# plt.text(500, 4.65, '1.0', size="small")


# fig.savefig('figures/standard_runs.png', bbox_inches='tight', dpi = 300)
# Out:
# Text(0, 0.5, 'Peak Warming (K)')

# %%
# np.savetxt("parameter_sensitivity_runs/Y_array_condition", Y_array, delimiter=",")

# %%
# np.savetxt("parameter_sensitivity_runs/SCC_0_array_condition", SCC_0_array, delimiter=",")

# %% [markdown]
# ### Plotting MAC curves for above

# %%
def abatement(P, P0, P_50, P_100, r=0.04, s=0.05):  # 0.05
    if P0 >= P_50:
        print("P0 is greater than P_50")
    elif ((P_100-P0)/(P_50-P0))**(s/r) <= 2:
        print("MAC curve condition not satisfied")
    
    P_h = P0 + ((P_50 - P0) ** (-s / r) - 2 * (P_100 - P0) ** (-s / r)) ** (-r / s)
    Am = 1 + ((P_100 - P0) / (P_h - P0)) ** (-s / r)
    
    A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
    
    return A

# %%
consumption_growth_array[2]
# Out:
# 0.02

# %%
fig = plt.figure()

# SCC_25 = np.arange(25, 1000)
consumption_growth = consumption_growth_array[2]

for i in range(len(param_values_2)):  # 20
    SCC = np.arange(SCC_0_array[2][i], 1000)
    P0 = SCC[0]
    P_50 = param_values_2[i][0]*param_values_2[i][1]
    P_100 = param_values_2[i][1]
    consumption_discount = consumption_growth + 0.015
    r = consumption_discount
#     constraint = param_values_2[i][1]
    s = r * np.log(5)/np.log((P_100)/(P_50))
#     if constraint >2.5:
#     print(constraint)
    plt.plot(abatement(SCC, P0=P0, P_100=P_100, P_50=P_50, r=r, s=s), SCC)

plt.xlabel("Abatement")
plt.ylabel("Carbon Price ($)")
plt.yscale("log")
# plt.legend(title="P0 ($)")
plt.ylim(20, 1000)

fig.savefig('figures/associated_MACC.png', bbox_inches='tight', dpi = 300)
# Out:
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# /var/folders/m4/mbpwp5q15070t8lqj4fj7mjr0000gn/T/ipykernel_66884/2643110261.py:10: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))

# %% [markdown]
# ### Looking at SCC_0

# %%
SCC_0_array[0]
# Out:
# array([33.68060694, 34.62732468, 34.52409639, 34.52409639, 34.62732468,
#        35.36811294, 36.30343136, 36.71878851, 32.54854263, 32.54854263,
#        36.71878851, 33.45135382, 33.80835727, 32.17466932, 36.49610846,
#        36.49610846, 32.17466932, 35.54984063, 35.31603422, 35.95198088,
#        34.00252734, 34.00252734, 35.95198088, 34.81546005, 31.30114971,
#        32.36499262, 33.46060964, 33.46060964, 32.36499262, 34.30473751,
#        35.93062906, 34.89730768, 36.39680525, 36.39680525, 34.89730768,
#        35.49147862, 34.46377411, 34.2055171 , 30.878951  , 30.878951  ,
#        34.2055171 , 30.49969978, 35.39901182, 35.11525502, 34.33986461,
#        34.33986461, 35.11525502, 33.99937709, 31.21095593, 32.37911532,
#        35.26161468, 35.26161468, 32.37911532, 35.96896235, 35.68974611,
#        34.35212952, 34.33795264, 34.33795264, 34.35212952, 32.67173823,
#        35.13429075, 34.92748178, 35.85159272, 35.85159272, 34.92748178,
#        35.67908577, 35.90056127, 35.67441613, 31.10258117, 31.10258117,
#        35.67441613, 30.70056496, 32.94637825, 32.57607209, 32.35603648,
#        32.35603648, 32.57607209, 31.96453468, 36.18161452, 36.01418135,
#        36.03708429, 36.03708429, 36.01418135, 35.8615298 , 30.29580145,
#        29.90322798, 34.75869806, 34.75869806, 29.90322798, 34.48855895,
#        33.81453191, 35.64785282, 35.27392009, 35.27392009, 35.64785282,
#        36.66025494])

# %%
df = pd.DataFrame(SCC_0_array, index=np.round(consumption_growth_array*100,3)).transpose()

# %%
df
# Out:
#           1.0        1.5        2.0        2.5        3.0        3.5
# 0   33.680607  31.803716  30.269391  29.008824  27.951578  27.055562
# 1   34.627325  32.767387  31.182082  29.882078  28.781161  27.843089
# 2   34.524096  32.706238  31.151217  29.877430  28.790807  27.861824
# 3   34.524096  32.706238  31.151217  29.877430  28.790807  27.861824
# 4   34.627325  32.767387  31.182082  29.882078  28.781161  27.843089
# ..        ...        ...        ...        ...        ...        ...
# 91  35.647853  33.854332  32.285482  30.954318  29.828612  28.850448
# 92  35.273920  33.555595  32.032570  30.740055  29.617233  28.691137
# 93  35.273920  33.555595  32.032570  30.740055  29.617233  28.691137
# 94  35.647853  33.854332  32.285482  30.954318  29.828612  28.850448
# 95  36.660255  35.102135  33.649519  32.338051  31.202384  30.184122
#
# [96 rows x 6 columns]

# %%
# df.boxplot(whis=100)

# %%
# colour_scheme = ["orange","blue","yellow","green","purple","red"]

# %%
fig = plt.figure()

for i,d in enumerate(df):
    y = df[df.columns[i]]
    x = np.random.normal(i+1, 0.05, len(y))  # consumption_growth_array[i]
    plt.plot(x, y, ms=5, marker="+", linestyle="None", color=cm.plasma(i/len(Y_array)))  #  mfc = colour_scheme[i],
    
# plt.boxplot(df, whis=100)
df.boxplot(whis=100)  # whiskerprops = dict(linewidth=1.5), boxprops = dict(linewidth=1.5), medianprops=dict(linewidth=2, color="gray"), flierprops=dict(linewidth=1.5), capprops=dict(linewidth=1.5)
plt.xlabel("Consumption Growth Rate  (% yr$^{-1}$)")
plt.ylabel("Social Cost of Carbon in 2020 ($)")

fig.savefig('figures/SCC.png', bbox_inches='tight', dpi = 300)

# %%
df_T = pd.DataFrame(T_year_array, index=np.round(consumption_growth_array,3)).transpose()

# %%
df_T
# Out:
#      0.010   0.015   0.020   0.025   0.030   0.035
# 0   2195.0  2148.0  2122.0  2105.0  2093.0  2084.0
# 1   2188.0  2144.0  2119.0  2103.0  2091.0  2083.0
# 2   2210.0  2159.0  2130.0  2112.0  2099.0  2089.0
# 3   2210.0  2159.0  2130.0  2112.0  2099.0  2089.0
# 4   2188.0  2144.0  2119.0  2103.0  2091.0  2083.0
# ..     ...     ...     ...     ...     ...     ...
# 91  2188.0  2144.0  2120.0  2104.0  2092.0  2084.0
# 92  2231.0  2173.0  2142.0  2121.0  2107.0  2096.0
# 93  2231.0  2173.0  2142.0  2121.0  2107.0  2096.0
# 94  2188.0  2144.0  2120.0  2104.0  2092.0  2084.0
# 95  2218.0  2166.0  2136.0  2117.0  2104.0  2094.0
#
# [96 rows x 6 columns]

# %%
# for i,d in enumerate(df_T):
#     y = df_T[df_T.columns[i]]
#     x = np.random.normal(i+1, 0.05, len(y))  # consumption_growth_array[i]
#     plt.plot(x, y, mec='k', ms=4, marker="o", linestyle="None") # # mfc = ["orange","blue","yellow","green","purple","red"][i]
    
# # plt.boxplot(df, whis=100)
# df_T.boxplot(whis=1000, whiskerprops = dict(linewidth=2), boxprops = dict(linewidth=2), medianprops=dict(linewidth=2, color="gray"), flierprops=dict(linewidth=2), capprops=dict(linewidth=2))
# plt.xlabel("Consumption Growth Rate")
# plt.ylabel("Year of Peak Warming")

# %%
# plt.scatter(df_T[df_T.columns[0]], Y_array[0], color=colour_scheme[0])

# %%
fig = plt.figure()

for i in range(df_T.shape[1]):
    plt.scatter(df_T[df_T.columns[i]], Y_array[i], label=np.round(consumption_growth_array[i]*100, 3), color=cm.plasma(i/len(Y_array)))

# plt.legend(title="g (% yr$^{-1}$)")
plt.xlabel("Year of Net Zero")
plt.ylabel("Peak Warming (K)")

plt.ylim(1.2, 5.2)

fig.savefig('figures/Year_of_Peak.png', bbox_inches='tight', dpi = 300)

# %%
df_T.shape[1]
# Out:
# 6

# %% [markdown]
# # Varying g

# %%
def vary_consumption_growth2_g(consumption_growth, P0_prime):
    Y = np.zeros([param_values_2.shape[0]])
    SCC_forecasted_0 = np.zeros([param_values_2.shape[0]])
    T_year_list = np.zeros([param_values_2.shape[0]])

#     consumption_growth = 0.020
    consumption_discount = consumption_growth + 0.015

    for i in range(len(param_values_2)):
        if i%8 == 0:
            print(i)
            t = time.localtime()
            current_time = time.strftime("%H:%M:%S", t)
            print(current_time)
        
        P_50 = param_values_2[i][0]*param_values_2[i][1]
        P_100 = param_values_2[i][1]
        r = consumption_discount
        s = r * np.log(5)/np.log((P_100)/(P_50))
        g_grad = 0.0026
#         g_grad = 0.0002
#         constraint = param_values_2[i][1]
#         s = r * np.log(constraint)/np.log((P_100 - P0)/(P_50 - P0))
#         s = r * np.log(constraint)/np.log((P_100)/(P_50))

        Y[i], SCC_forecasted, forecasted_abatement, forecasted_emissions, T_complete = varying_g_peak_warming_calculator(P_50=P_50, P_100=P_100, g_2019=consumption_growth, consumption_discount=consumption_discount, return_all_output=True, s=s, r=r, P0_prime=P0_prime[i], g_grad=g_grad)  # P0_prime[i] 
        SCC_forecasted_0[i] = SCC_forecasted[0]
        start_year = 1750
        peak_T = Y[i]
        T_year_list[i] = next(x[0] for x in enumerate(T_complete) if x[1] == peak_T) + start_year
        if Y[i] < 1.4:
            print(param_values_2[i][0])
            print(param_values_2[i][1])
            print(consumption_discount)
    return Y, SCC_forecasted_0, T_year_list

# %%
# Y, SCC_forecasted_0, T_year_list

# %%
SCC_0_array
# Out:
# [array([33.68060694, 34.62732468, 34.52409639, 34.52409639, 34.62732468,
#         35.36811294, 36.30343136, 36.71878851, 32.54854263, 32.54854263,
#         36.71878851, 33.45135382, 33.80835727, 32.17466932, 36.49610846,
#         36.49610846, 32.17466932, 35.54984063, 35.31603422, 35.95198088,
#         28.63924553, 28.44470523, 28.44470523, 28.63924553, 27.05883838,
#         29.23503662, 29.03001451, 30.05527001, 30.05527001, 29.03001451,
#         29.88800091, 30.23910172, 29.99455248, 25.63240937, 25.63240937,
#         29.99455248, 25.32942256, 27.19864166, 26.89533224, 26.68401129,
#         26.68401129, 26.89533224, 26.37495486, 30.51247748, 30.31339235,
#         30.31392935, 30.31392935, 30.31339235, 30.11067484, 24.99484123,
#         24.70162853, 28.90281866, 28.90281866, 24.70162853, 28.65539712,
#         28.10407432, 29.82861194, 29.61723343, 29.61723343, 29.82861194,
#         31.20238392]),
#  array([27.05556238, 27.84308856, 27.86182405, 27.86182405, 27.84308856,
#         28.62004368, 29.72921018, 30.26534451, 25.97786316, 25.97786316,
#         30.26534451, 26.64576278, 26.97786412, 25.74778558, 29.94519829,
#         29.94519829, 25.74778558, 28.92260927, 28.60386903, 29.21867733,
#         27.27697864, 27.27697864, 29.21867733, 27.97401176, 24.9960962 ,
#         25.7292978 , 26.75847377, 26.75847377, 25.7292978 , 27.43663336,
#         29.18480415, 28.14822718, 29.77506198, 29.77506198, 28.14822718,
#         28.8043927 , 27.62425612, 27.40277281, 24.64839575, 24.64839575,
#         27.40277281, 24.39746658, 28.74717454, 28.48368949, 27.62850309,
#         27.62850309, 28.48368949, 27.35078783, 24.98307921, 25.81158292,
#         28.61792849, 28.61792849, 25.81158292, 29.29490953, 28.94090989,
#         27.71792963, 27.51534778, 27.51534778, 27.71792963, 26.20594859,
#         28.27403344, 28.07750134, 29.0961019 , 29.0961019 , 28.07750134,
#         28.91034775, 29.24952954, 29.0144601 , 24.86145836, 24.86145836,
#         29.0144601 , 24.58097592, 26.36783541, 26.08564871, 25.88866057,
#         25.88866057, 26.08564871, 25.60218416, 29.50994493, 29.31657049,
#         29.31489501, 29.31489501, 29.31657049, 29.1514004 , 24.26741614,
#         23.99628956, 27.95889264, 27.95889264, 23.99628956, 27.72295856,
#         27.20383033, 28.85044818, 28.69113671, 28.69113671, 28.85044818,
#         30.18412224])]

# %%
P0_prime_array = SCC_0_array

# %%
Y_array_2 = []
SCC_0_array_2 = []
T_year_array_2 = []

for i in range(len(consumption_growth_array)):  # len(consumption_growth_array)
    Y, SCC_0, T_year = vary_consumption_growth2_g(consumption_growth_array[i], P0_prime_array[i])
    Y_array_2.append(Y)
    SCC_0_array_2.append(SCC_0)
    T_year_array_2.append(T_year)
# Out:
# 0
# 17:06:04
# /Users/aaron/Documents/oxford_physics/Year_4/MPhys/drivers-of-peak-warming/peak_warming_calculator/varying_g_peak_warming_calculator.py:291: RuntimeWarning: divide by zero encountered in power
#   A = Am / (1 + ((P - P0) / (P_h - P0)) ** (-s / r))
# 8
# 17:06:20
# 16
# 17:06:34
# 24
# 17:06:46
# 0.640625
# 137.5
# 0.025
# 32
# 17:06:54
# 0.7156250000000001
# 112.5
# 0.025
# 0.7156250000000001
# 112.5
# 0.025
# 40
# 17:07:06
# 0.6781250000000001
# 112.5
# 0.025
# 48
# 17:07:20
# 56
# 17:07:33
# 64
# 17:07:44
# 0.621875
# 137.5
# 0.025
# 0.621875
# 137.5
# 0.025
# 0.584375
# 137.5
# 0.025
# 72
# 17:07:56
# 80
# 17:08:05
# 0.659375
# 112.5
# 0.025
# 0.621875
# 112.5
# 0.025
# 287.5
# 0.05
# 8
# 17:14:02
# 0.6781250000000001
# 162.5
# 0.05
# 0.6781250000000001
# 162.5
# 0.05
# 0.790625
# 162.5
# 0.05
# 0.753125
# 187.5
# 0.05
# 0.565625
# 187.5
# 0.05
# 16
# 17:14:06
# 0.565625
# 187.5
# 0.05
# 0.603125
# 262.5
# 0.05
# 0.603125
# 262.5
# 0.05
# 0.7156250000000001
# 262.5
# 0.05
# 24
# 17:14:10
# 0.640625
# 137.5
# 0.05
# 0.753125
# 137.5
# 0.05
# 0.640625
# 212.5
# 0.05
# 0.640625
# 212.5
# 0.05
# 0.753125
# 137.5
# 0.05
# 0.753125
# 212.5
# 0.05
# 0.603125
# 337.5
# 0.05
# 32
# 17:14:14
# 0.603125
# 337.5
# 0.05
# 0.7156250000000001
# 237.5
# 0.05
# 0.6781250000000001
# 237.5
# 0.05
# 0.7156250000000001
# 112.5
# 0.05
# 0.7156250000000001
# 112.5
# 0.05
# 40
# 17:14:18
# 0.6781250000000001
# 237.5
# 0.05
# 0.6781250000000001
# 112.5
# 0.05
# 0.565625
# 312.5
# 0.05
# 0.565625
# 312.5
# 0.05
# 0.528125
# 312.5
# 0.05
# 48
# 17:14:22
# 0.546875
# 162.5
# 0.05
# 0.659375
# 162.5
# 0.05
# 0.659375
# 162.5
# 0.05
# 0.509375
# 362.5
# 0.05
# 56
# 17:14:26
# 0.696875
# 237.5
# 0.05
# 0.696875
# 237.5
# 0.05
# 0.509375
# 362.5
# 0.05
# 0.509375
# 237.5
# 0.05
# 0.7718750000000001
# 262.5
# 0.05
# 0.734375
# 262.5
# 0.05
# 64
# 17:14:30
# 0.734375
# 262.5
# 0.05
# 0.621875
# 137.5
# 0.05
# 0.621875
# 137.5
# 0.05
# 0.584375
# 137.5
# 0.05
# 72
# 17:14:34
# 0.584375
# 212.5
# 0.05
# 0.546875
# 212.5
# 0.05
# 0.584375
# 187.5
# 0.05
# 0.584375
# 187.5
# 0.05
# 0.546875
# 212.5
# 0.05
# 0.546875
# 187.5
# 0.05
# 80
# 17:14:38
# 0.659375
# 112.5
# 0.05
# 0.621875
# 112.5
# 0.05
# 0.659375
# 287.5
# 0.05
# 0.659375
# 287.5
# 0.05
# 88
# 17:14:43
# 0.621875
# 112.5
# 0.05
# 0.621875
# 287.5
# 0.05
# 0.509375
# 312.5
# 0.05

# %%
fig = plt.figure()

## plot output

for i in range(len(Y_array)):
    plt.scatter(P_100_list, Y_array_2[i], label=np.round(consumption_growth_array[i]*100, 3), color=cm.plasma(i/len(Y_array)))

# plt.legend()
plt.rc('font', family='serif')

## plot curves from Myles' paper

# W0 = 75*10**12  
W0 = 80*10**12  
D0 = 0.00267
T_TCRE = 0.00054  # degrees Celsius per GtCO2
# note: this corresponds to 0.002 degrees Celsius per GtC
r_minus_g = 0.015  # 1.5%
ks = 0.12  # per year

G = W0*D0*T_TCRE*(1/(r_minus_g)-1/(ks+r_minus_g))

gamma = 2
# E_0 = 39  # 2014 level of emissions
# percentage_of_emissions = 0.75  # set here the percentage of emisison
# E_bar = percentage_of_emissions*E_0
E_bar = 0.75*40.040508
# T_0 = 0.9  # 1.0136929156818866  # degrees Celsius
# T_0 = 1.0136929156818866
T_0 = 1.2

T_m = np.arange(T_0, 5,0.1)
g_bar = np.arange(0.01, 0.04, 0.005)

for i in range(len(g_bar)):
    A_B = gamma*G*(T_m**(gamma-1))*np.exp((g_bar[i]/E_bar) * (T_m-T_0)/T_TCRE)
#     print(gamma, G, T_m)
#     print(np.exp((g_bar[i]/E_bar) * (T_m-T_0)/T_TCRE))
#     plt.plot(A_B*10**(-9), T_m, color="k")  # convert cost into trillions of dollars # , label=g_bar[i]
    plt.plot(A_B*10**(-9), T_m, color=cm.plasma(i/len(g_bar)))

plt.legend(title="g$_{0}$ (% yr$^{-1}$)", loc="center left")
# plt.xlim(0, 525)
plt.xlim(0, 500)
plt.ylim(1.2, 2.7)
plt.xlabel("Adjusted Carbon Price at 100% Abatement ($)")
plt.ylabel("Peak Warming (K)")

# plt.text(320, 2.32, '3.5', size="small")
# plt.text(275, 2.41, '3.0', size="small")
# plt.text(215, 2.48, '2.5', size="small")
# plt.text(155, 2.54, '2.0', size="small")
# plt.text(102, 2.6, '1.5', size="small")
# plt.text(60, 2.62, '1.0', size="small")

fig.savefig('figures/standard_runs_varying_g.png', bbox_inches='tight', dpi = 300)

# %%
df_T_2 = pd.DataFrame(T_year_array_2, index=np.round(consumption_growth_array*100,3)).transpose()

# %%
fig = plt.figure()

for i in range(df_T_2.shape[1]):
    plt.scatter(df_T_2[df_T_2.columns[i]], Y_array_2[i], label=np.round(consumption_growth_array[i]*100, 3), color=cm.plasma(i/len(Y_array)))

# plt.legend(title="g$_{0}$  (% yr$^{-1}$)")
plt.xlabel("Year of Net Zero")
plt.ylabel("Peak Warming (K)")
# plt.xlim(2000, 2100)
# plt.ylim(1, 2.5)
plt.ylim(1.2, 2.7)

fig.savefig('figures/Year_of_Peak_varying_g.png', bbox_inches='tight', dpi = 300)

# %%
T_year_array_2[0]
# Out:
# array([2060., 2058., 2071., 2071., 2058., 2070., 2089., 2088., 2040.,
#        2040., 2088., 2038., 2042., 2045., 2084., 2084., 2045., 2085.,
#        2074., 2073., 2055., 2055., 2073., 2054., 2036., 2035., 2047.,
#        2047., 2035., 2046., 2064., 2066., 2076., 2076., 2066., 2078.,
#        2050., 2051., 2032., 2032., 2051., 2032., 2082., 2082., 2063.,
#        2063., 2082., 2063., 2041., 2040., 2082., 2082., 2040., 2081.,
#        2069., 2071., 2050., 2050., 2071., 2053., 2053., 2054., 2065.,
#        2065., 2054., 2065., 2085., 2085., 2037., 2037., 2085., 2037.,
#        2048., 2048., 2044., 2044., 2048., 2045., 2077., 2077., 2073.,
#        2073., 2077., 2073., 2033., 2033., 2058., 2058., 2033., 2059.,
#        2064., 2061., 2089., 2089., 2061., 2088.])

# %%
param_values_2[0]
# Out:
# array([  0.528125, 287.5     ])

# %%
SCC_0_array[0][0]
# Out:
# 33.68060693634358

# %%
Y_array_2[0][0]
# Out:
# 1.6173124083234036

# %%
df_2 = pd.DataFrame(SCC_0_array_2, index=np.round(consumption_growth_array,3)).transpose()

# %%
fig = plt.figure()

for i,d in enumerate(df_2):
    y = df_2[df_2.columns[i]]
    x = np.random.normal(i+1, 0.05, len(y))  # consumption_growth_array[i]
    plt.plot(x, y, ms=5, marker="+", linestyle="None", color=cm.plasma(i/len(Y_array)))  #  mfc = colour_scheme[i],
    
# plt.boxplot(df, whis=100)
df.boxplot(whis=100)  # whiskerprops = dict(linewidth=1.5), boxprops = dict(linewidth=1.5), medianprops=dict(linewidth=2, color="gray"), flierprops=dict(linewidth=1.5), capprops=dict(linewidth=1.5)
plt.xlabel("Consumption Growth Rate")
plt.ylabel("Social Cost of Carbon in 2019 ($)")

# fig.savefig('figures/SCC_varying_g.png', bbox_inches='tight', dpi = 300)
# Out:
# Text(0, 0.5, 'Social Cost of Carbon in 2019 ($)')

# %%
SCC_0_array
# Out:
# [array([33.68060694, 34.62732468, 34.52409639, 34.52409639, 34.62732468,
#         35.36811294, 36.30343136, 36.71878851, 32.54854263, 32.54854263,
#         36.71878851, 33.45135382, 33.80835727, 32.17466932, 36.49610846,
#         36.49610846, 32.17466932, 35.54984063, 35.31603422, 35.95198088,
#         34.00252734, 34.00252734, 35.95198088, 34.81546005, 31.30114971,
#         32.36499262, 33.46060964, 33.46060964, 32.36499262, 34.30473751,
#         35.93062906, 34.89730768, 36.39680525, 36.39680525, 34.89730768,
#         35.49147862, 34.46377411, 34.2055171 , 30.878951  , 30.878951  ,
#         34.2055171 , 30.49969978, 35.39901182, 35.11525502, 34.33986461,
#         34.33986461, 35.11525502, 33.99937709, 31.21095593, 32.37911532,
#         35.26161468, 35.26161468, 32.37911532, 35.96896235, 35.68974611,
#         34.35212952, 34.33795264, 34.33795264, 34.35212952, 32.67173823,
#         35.13429075, 34.92748178, 35.85159272, 35.85159272, 34.92748178,
#         35.67908577, 35.90056127, 35.67441613, 31.10258117, 31.10258117,
#         35.67441613, 30.70056496, 32.94637825, 32.57607209, 32.35603648,
#         32.35603648, 32.57607209, 31.96453468, 36.18161452, 36.01418135,
#         36.03708429, 36.03708429, 36.01418135, 35.8615298 , 30.29580145,
#         29.90322798, 34.75869806, 34.75869806, 29.90322798, 34.48855895,
#         33.81453191, 35.64785282, 35.27392009, 35.27392009, 35.64785282,
#         36.66025494]),
#  array([31.80371563, 32.7673872 , 32.70623848, 32.70623848, 32.7673872 ,
#         33.56842062, 34.67379328, 35.17543166, 30.58308286, 30.58308286,
#         35.17543166, 31.43934009, 31.83906892, 30.23689379, 34.89244084,
#         34.89244084, 30.23689379, 33.83549888, 33.54382299, 34.22407551,
#         32.1132368 , 32.1132368 , 34.22407551, 32.92775461, 29.38098567,
#         30.37867408, 31.51399925, 31.51399925, 30.37867408, 32.36898143,
#         34.18571682, 33.07120055, 34.75418281, 34.75418281, 33.07120055,
#         33.74592604, 32.56469648, 32.29903071, 28.98202482, 28.98202482,
#         32.29903071, 28.63775806, 33.66086916, 33.36208477, 32.4816543 ,
#         32.4816543 , 33.36208477, 32.14086473, 29.33698697, 30.41804099,
#         33.51546119, 33.51546119, 30.41804099, 34.26886516, 33.91716902,
#         32.53256788, 32.43468234, 32.43468234, 32.53256788, 30.76474342,
#         33.26560159, 33.04543585, 34.09542414, 34.09542414, 33.04543585,
